# %%
import cv2
import pywhatkit
import numpy as np
import os
import warnings
import smtplib
import imghdr
from email.message import EmailMessage
from datetime import datetime
from os import listdir
from os.path import isfile, join
import subprocess

# %%
### Step 1 - Create Training Data

# Load HAAR face classifier
warnings. filterwarnings(action='ignore')
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Load functions
def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.5, 5)
    
    if faces ==():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

# Initialize Webcam
cap = cv2.VideoCapture(0)
count = 0

# Collect 100 samples of your face from webcam input
while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        face = cv2.resize(face_extractor(frame), (400, 400))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Save file in specified directory with unique name
        file_name_path = 'face/Dataset1/' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        print("Face not found")

    if cv2.waitKey(1) == 13 or count == 200: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()      
print("Collecting Samples Complete")
cap.release()
# Out:
# Collecting Samples Complete

# %%
# Load HAAR face classifier
warnings. filterwarnings(action='ignore')
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Load functions
def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.5, 5)
    
    if faces ==():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

# Initialize Webcam
cap = cv2.VideoCapture(0)
count = 0

# Collect 100 samples of your face from webcam input
while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        face = cv2.resize(face_extractor(frame), (400, 400))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Save file in specified directory with unique name
        file_name_path = './face/Dataset2/' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        print("Face not found")
#        pass

    if cv2.waitKey(1) == 13 or count == 200: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()      
print("Collecting Samples Complete")
cap.release()
# Out:
# Collecting Samples Complete

# %%
# Get the training data we previously made

training_data = []
labels = []

#1
data_path = './face/Dataset1/'
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]

for i, files in enumerate(onlyfiles):
    img_path = data_path + onlyfiles[i]
    images = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    training_data.append(np.asarray(images, dtype=np.uint8))
    labels.append(1)
#2
data_path = './face/Dataset2/'
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]

for i, files in enumerate(onlyfiles):
    img_path = data_path + onlyfiles[i]
    images = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    training_data.append(np.asarray(images, dtype=np.uint8))
    labels.append(2)
    
    

    
labels = np.asarray(labels, dtype=np.int32)

model = cv2.face_LBPHFaceRecognizer.create()

model.train(np.asarray(training_data), np.asarray(labels))

model.write('model_save.yml')

print("Model trained sucessefully")
# Out:
# Model trained sucessefully

# %%
def mail(img):
    Sender_Email = "amandevv21@gmail.com"
    Reciever_Email = "amandevverma1999@gmail.com"
    Password=""
    h = open("pass.txt", "r")
    for line in h:
        Password=line 
    h.close()
    print("mail running")
    newMessage = EmailMessage()                         
    newMessage['Subject'] = "Face Successfullly detected" 
    newMessage['From'] = Sender_Email                   
    newMessage['To'] = Reciever_Email                   
    newMessage.set_content('Image attached!')
    
    cv2.imwrite("face.jpg",img)
    with open('face.jpg', 'rb') as f:
        image_data = f.read()
        image_type = imghdr.what(f.name)
        image_name = f.name
        
    newMessage.add_attachment(image_data, maintype='image', subtype=image_type, filename=image_name)
    
    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
        smtp.login(Sender_Email, Password)              
        smtp.send_message(newMessage)
        print("Mail send successfully")
        


def whatsapp():
    now = datetime.now()
    H = int(now.strftime("%H"))
    M = int(now.strftime("%M"))
    pywhatkit.sendwhatmsg('+919990345500', 'HEY!! FACE DETECTED',H,M+1)
    print("Whatsaap msg send successfully")
def aws():
    subprocess.getoutput("terraform init")
    subprocess.getoutput('terraform apply --auto-approve')
    print("An instance is launched on AWS and 1 GB EBS volume attached to it")

# %%
warnings. filterwarnings(action='ignore')

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

model = cv2.face_LBPHFaceRecognizer.create()
model.read('model_save.yml')

def face_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces == ():
        return img, []
    
    
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),1)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi


# Open Webcam
cap = cv2.VideoCapture(0)
while True:

    ret, frame = cap.read()
    
    image, face = face_detector(frame)
    
    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        results = model.predict(face)
        if results[1] < 500:
            confidence = int( 100 * (1 - (results[1])/400) )
            display_string = str(confidence) + '% Confident'
            
        
        
        if results[0]==1:
            if (confidence > 80):
                
                cv2.putText(image, "Hello, Aman", (250, 450), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)
                cv2.putText(image, display_string, (0, 50), cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 1, (255,255,250), 2)
                cv2.imshow('Face Recognition', image )
                if(cv2.waitKey(2)==13): #   13 is the Enter Key
                    mail(face)
                    whatsapp()
                    
                    
                
        elif(results[0]==2):
            if (confidence > 80):
                cv2.putText(image, "Hello, Khushboo", (250, 450), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)
                cv2.putText(image, display_string, (0, 50), cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 1, (255,255,250), 2)
                cv2.imshow('Face Recognition', image )
                if(cv2.waitKey(2)==13):
                    aws()
                    
            

         
        else: 
            cv2.putText(image, "Unknown Person", (250, 450), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )

    except:
        cv2.putText(image, "NO FACE FOUND", (220, 120) , cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "Looking for Face", (250, 450), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        
    if cv2.waitKey(1) == 32: #   32 is the spacebar Key
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# mail running
# Mail send successfully
# mail running
# Mail send successfully
# In 8 seconds web.whatsapp.com will open and after 20 seconds message will be delivered
# Whatsaap msg send successfully
# An instance is launched on AWS and 1 GB EBS volume attached to it

# %%
import subprocess
subprocess.getoutput('terraform destroy --auto-approve')
# Out:
# '\x1b\x1baws_instance.os1: Refreshing state... [id=i-05c082c6e76a10f68]\x1b\n\x1b\x1baws_ebs_volume.myExtraHDD: Refreshing state... [id=vol-0b84c989db606531c]\x1b\n\x1b\x1baws_volume_attachment.ebs_att: Refreshing state... [id=vai-1631158996]\x1b\n\x1b\n\x1b\x1bNote:\x1b\x1b Objects have changed outside of Terraform\x1b\n\n\x1bTerraform detected the following changes made outside of Terraform since the\nlast "terraform apply":\n\n\x1b  # aws_instance.os1\x1b has been changed\x1b\x1b\n\x1b  \x1b~\x1b\x1b resource "aws_instance" "os1" {\n        \x1b\x1bid\x1b\x1b                                   = "i-05c082c6e76a10f68"\n        \x1b\x1btags\x1b\x1b                                 = {\n            "Name" = "face detected"\n        }\n        \x1b# (28 unchanged attributes hidden)\x1b\x1b\n\n\n\n      \x1b+\x1b \x1bebs_block_device {\n          \x1b+\x1b \x1b\x1b\x1bdelete_on_termination\x1b\x1b = false\n          \x1b+\x1b \x1b\x1b\x1bdevice_name\x1b\x1b           = "/dev/sdh"\n          \x1b+\x1b \x1b\x1b\x1bencrypted\x1b\x1b             = false\n          \x1b+\x1b \x1b\x1b\x1biops\x1b\x1b                  = 100\n          \x1b+\x1b \x1b\x1b\x1btags\x1b\x1b                  = {\n              \x1b+\x1b \x1b"Name" = "MyExtraHDD"\n            }\n          \x1b+\x1b \x1b\x1b\x1bthroughput\x1b\x1b            = 0\n          \x1b+\x1b \x1b\x1b\x1bvolume_id\x1b\x1b             = "vol-0b84c989db606531c"\n          \x1b+\x1b \x1b\x1b\x1bvolume_size\x1b\x1b           = 1\n          \x1b+\x1b \x1b\x1b\x1bvolume_type\x1b\x1b           = "gp2"\n        }\n\n\n\n        \x1b# (5 unchanged blocks hidden)\x1b\x1b\n    }\n\nUnless you have made equivalent changes to your configuration, or ignored the\nrelevant attributes using ignore_changes, the following plan may include\nactions to undo or respond to these changes.\n\x1b\nâ”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€\x1b\n\nTerraform used the selected providers to generate the following execution\nplan. Resource actions are indicated with the following symbols:\n  \x1b-\x1b destroy\n\x1b\nTerraform will perform the following actions:\n\n\x1b  # aws_ebs_volume.myExtraHDD\x1b will be \x1b\x1bdestroyed\x1b\x1b\n\x1b  \x1b-\x1b\x1b resource "aws_ebs_volume" "myExtraHDD" {\n      \x1b-\x1b \x1b\x1b\x1barn\x1b\x1b                  = "arn:aws:ec2:ap-south-1:309454527441:volume/vol-0b84c989db606531c" \x1b->\x1b \x1b\x1bnull\x1b\x1b\n      \x1b-\x1b \x1b\x1b\x1bavailability_zone\x1b\x1b    = "ap-south-1a" \x1b->\x1b \x1b\x1bnull\x1b\x1b\n      \x1b-\x1b \x1b\x1b\x1bencrypted\x1b\x1b            = false \x1b->\x1b \x1b\x1bnull\x1b\x1b\n      \x1b-\x1b \x1b\x1b\x1bid\x1b\x1b                   = "vol-0b84c989db606531c" \x1b->\x1b \x1b\x1bnull\x1b\x1b\n      \x1b-\x1b \x1b\x1b\x1biops\x1b\x1b                 = 100 \x1b->\x1b \x1b\x1bnull\x1b\x1b\n      \x1b-\x1b \x1b\x1b\x1bmulti_attach_enabled\x1b\x1b = false \x1b->\x1b \x1b\x1bnull\x1b\x1b\n      \x1b-\x1b \x1b\x1b\x1bsize\x1b\x1b                 = 1 \x1b->\x1b \x1b\x1bnull\x1b\x1b\n      \x1b-\x1b \x1b\x1b\x1btags\x1b\x1b                 = {\n          \x1b-\x1b \x1b"Name" = "MyExtraHDD"\n        } \x1b->\x1b \x1b\x1bnull\x1b\x1b\n      \x1b-\x1b \x1b\x1b\x1btags_all\x1b\x1b             = {\n          \x1b-\x1b \x1b"Name" = "MyExtraHDD"\n        } \x1b->\x1b \x1b\x1bnull\x1b\x1b\n      \x1b-\x1b \x1b\x1b\x1bthroughput\x1b\x1b           = 0 \x1b->\x1b \x1b\x1bnull\x1b\x1b\n      \x1b-\x1b \x1b\x1b\x1btype\x1b\x1b                 = "gp2" \x1b->\x1b \x1b\x1bnull\x1b\x1b\n    }\n\n\x1b  # aws_instance.os1\x1b will be \x1b\x1bdestroyed\x1b\x1b\n\x1b  \x1b-\x1b\x1b resource "aws_instance" "os1" {\n      \x1b-\x1b \x1b\x1b\x1bami\x1b\x1b                                  = "ami-06a0b4e3b7eb7a300" \x1b->\x1b \x1b\x1bnull\x1b\x1b\n      \x1b-\x1b \x1b\x1b\x1barn\x1b\x1b         ...

# %%
aws()
